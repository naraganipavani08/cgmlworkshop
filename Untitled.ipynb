# %%
#Import libraries
import numpy as np #Faster Data processing (arrays)
import pandas as pd

# %%
#Loading the data
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 118.9 KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
data.dtypes;
data.select_dtypes(include='object')
data.select_dtypes(include = ['int','float'])
# Out:
# C:\Users\narag\AppData\Local\Temp\ipykernel_24204\3863863315.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 886          887         0       2  27.0      0      0  13.0000
# 887          888         1       1  19.0      0      0  30.0000
# 888          889         0       3   NaN      1      2  23.4500
# 889          890         1       1  26.0      0      0  30.0000
# 890          891         0       3  32.0      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
print('Total number of passengers in the ship are',len(data))
# Out:
# Total number of passengers in the ship are 891

# %%
data.describe(include='object')
# Out:
# C:\Users\narag\AppData\Local\Temp\ipykernel_24204\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Sex'].unique()
# Out:
# <ArrowStringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['SibSp'].unique()
# Out:
# array([1, 0, 3, 4, 2, 5, 8])

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [raw]
# data['Embarked'].value_counts()

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass  \
# 64            65         0       1
# 183          184         1       2
# 670          671         1       2
# 751          752         1       3
# 241          242         1       3
# 535          536         1       2
# 591          592         1       1
# 791          792         0       2
# 198          199         1       3
# 61            62         1       1
# 119          120         0       3
# 215          216         1       1
# 274          275         1       3
# 371          372         0       3
# 115          116         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 64                               Stewart, Mr. Albert A    male   NaN      0
# 183                          Becker, Master. Richard F    male   1.0      2
# 670  Brown, Mrs. Thomas William Solomon (Elizabeth ...  female  40.0      1
# 751                                Moor, Master. Meier    male   6.0      0
# 241                     Murphy, Miss. Katherine "Kate"  female   NaN      1
# 535                             Hart, Miss. Eva Miriam  female   7.0      0
# 591    Stephenson, Mrs. Walter Bertram (Martha Eustis)  female  52.0      1
# 791                                Gaskell, Mr. Alfred    male  16.0      0
# 198                   Madigan, Miss. Margaret "Maggie"  female   NaN      0
# 61                                 Icard, Miss. Amelie  female  38.0      0
# 119                  Andersson, Miss. Ellis Anna Maria  female   2.0      4
# 215                            Newell, Miss. Madeleine  female  31.0      1
# 274                         Healy, Miss. Hanora "Nora"  female   NaN      0
# 371                          Wiklund, Mr. Jakob Alfred    male  18.0      1
# 115                              Pekoniemi, Mr. Edvard    male  21.0      0
#
#      Parch             Ticket      Fare Cabin Embarked
# 64       0           PC 17605   27.7208   NaN        C
# 183      1             230136   39.0000    F4        S
# 670      1              29750   39.0000   NaN        S
# 751      1             392096   12.4750  E121        S
# 241      0             367230   15.5000   NaN        Q
# 535      2       F.C.C. 13529   26.2500   NaN        S
# 591      0              36947   78.2667   D20        C
# 791      0             239865   26.0000   NaN        S
# 198      0             370370    7.7500   NaN        Q
# 61       0             113572   80.0000   B28      NaN
# 119      2             347082   31.2750   NaN        S
# 215      0              35273  113.2750   D36        C
# 274      0             370375    7.7500   NaN        Q
# 371      0            3101267    6.4958   NaN        S
# 115      0  STON/O 2. 3101294    7.9250   NaN        S

# %%
import matplotlib.pyplot as plt

# %%
counts,edges,bars = plt.hist(data['Age'],bins=15,color='violet')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age Distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
  data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
data['Pclass'].value_counts().plot(kind='bar',color = 'red')
# Out:
# <Axes: xlabel='Pclass'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived Distribution")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %% [raw]
# index=data['Survived'].value_counts().keys().tolist()
# print(index)
# labels=data['Survived'].value_counts().values.tolist()
# print(labels)

# %%
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
plt.pie(x = labels,
        labels=['Dead','Alive'],
        colors=['red','yellow'],
        autopct="%,1f",
        shadow=True)
plt.title("Survived Distribution",colors='green')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.pie(x = labels,
#       2         labels=['Dead','Alive'],
#       3         colors=['red','yellow'],
#       4         autopct="%,1f",
#
#     [... skipping hidden 1 frame]
#
# File ~\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File ~\ml_workshop_env\Lib\site-packages\matplotlib\axes\_axes.py:3753, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3751 for frac in fracs:
#    3752     if isinstance(autopct, str):
# -> 3753         s = autopct % (100. * frac)
#    3754     elif callable(autopct):
#    3755         s = autopct(100. * frac)
#
# ValueError: unsupported format character ',' (0x2c) at index 1

# %%
plt.pie(x = [577,314],
        labels=['M','F'],
        colors=['orange','green'],
        autopct="%,1f",
        shadow=True)
plt.title("Survived Distribution",colors='green')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 plt.pie(x = [577,314],
#       2         labels=['M','F'],
#       3         colors=['orange','green'],
#       4         autopct="%,1f",
#
#     [... skipping hidden 1 frame]
#
# File ~\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
#    3994         autopct=autopct,
#    3995         pctdistance=pctdistance,
#    3996         shadow=shadow,
#    3997         labeldistance=labeldistance,
#    3998         startangle=startangle,
#    3999         radius=radius,
#    4000         counterclock=counterclock,
#    4001         wedgeprops=wedgeprops,
#    4002         textprops=textprops,
#    4003         center=center,
#    4004         frame=frame,
#    4005         rotatelabels=rotatelabels,
#    4006         normalize=normalize,
#    4007         hatch=hatch,
#    4008         **({"data": data} if data is not None else {}),
#    4009     )
#
#     [... skipping hidden 2 frame]
#
# File ~\ml_workshop_env\Lib\site-packages\matplotlib\axes\_axes.py:3753, in Axes.pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch)
#    3751 for frac in fracs:
#    3752     if isinstance(autopct, str):
# -> 3753         s = autopct % (100. * frac)
#    3754     elif callable(autopct):
#    3755         s = autopct(100. * frac)
#
# ValueError: unsupported format character ',' (0x2c) at index 1

# %%
plt.scatter(x=data['Age'],
            y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.title("Age vs Fare Distribution")
plt.show()

# %%
import plotly

# %%
# !pip install cufflinks
# Out:
# Requirement already satisfied: cufflinks in c:\users\narag\ml_workshop_env\lib\site-packages (0.17.3)
# Requirement already satisfied: numpy>=1.9.2 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (2.5.1)
# Requirement already satisfied: pandas>=0.19.2 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (3.0.5)
# Requirement already satisfied: plotly>=4.1.1 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (6.9.0)
# Requirement already satisfied: six>=1.9.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (1.17.0)
# Requirement already satisfied: colorlover>=0.2.1 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (0.3.0)
# Requirement already satisfied: setuptools>=34.4.1 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (83.0.0)
# Requirement already satisfied: ipython>=5.3.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (9.16.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from cufflinks) (8.1.8)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (3.0.53)
# Requirement already satisfied: psutil>=7 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipython>=5.3.0->cufflinks) (5.16.1)
# Requirement already satisfied: comm>=0.1.3 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\narag\ml_workshop_env\lib\site-packages (from ipywidgets>=7.0.0->cufflinks) (3.0.16)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\narag\ml_workshop_env\lib\site-packages (from pandas>=0.19.2->cufflinks) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\narag\ml_workshop_env\lib\site-packages (from pandas>=0.19.2->cufflinks) (2026.3)
# Requirement already satisfied: narwhals>=1.15.1 in c:\users\narag\ml_workshop_env\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.24.0)
# Requirement already satisfied: packaging in c:\users\narag\ml_workshop_env\lib\site-packages (from plotly>=4.1.1->cufflinks) (26.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in c:\users\narag\ml_workshop_env\lib\site-packages (from jedi>=0.18.2->ipython>=5.3.0->cufflinks) (0.8.7)
# Requirement already satisfied: wcwidth>=0.1.4 in c:\users\narag\ml_workshop_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks) (0.8.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\narag\ml_workshop_env\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (3.0.2)
# Requirement already satisfied: pure-eval in c:\users\narag\ml_workshop_env\lib\site-packages (from stack_data>=0.6.0->ipython>=5.3.0->cufflinks) (0.2.3)
# [notice] A new release of pip is available: 25.0.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import plotly as py
import plotly.graph_objects as go

# %%
trace = go.Histogram(x = data['Age'], nbinsx=20, marker={'color' : 'plum'})
layout = go.Layout(title="Age Distribution")
fig = go.Figure(data=trace,layout = layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
trace = go.Pie(labels=['Dead','Alive'],
               values=[549,342],
              )
layout = go.Layout(title = 'Survived Distribution')
fig = go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace=go.Box(x=data['Pclass'],y=data['Age'],marker={'color':'slateblue'})
layout=go.Layout(title="Age vs Pclass Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],marker={'color':'violet'})
layout=go.Layout(title='Age VS Fare Distribution')
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
trace = go.Scatter(x=data['Age'],y=data['Fare'],mode='markers',marker={'color':'violet'})
layout=go.Layout(title='Age VS Fare Distribution')
fig = go.Figure(data=trace, layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(data['Age'].mean())
# Out:
# 29.69911764705882

# %%
data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True);
data.isnull().sum()
# Out:
# C:\Users\narag\AppData\Local\Temp\ipykernel_24204\3788167866.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age'] = data['Age'].fillna(data['Age'].mean(),inplace=True);
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
pclass = pd.get_dummies(data['Pclass'],drop_first=True,dtype=int)
pclass
# Out:
#      2  3
# 0    0  1
# 1    0  0
# 2    0  1
# 3    0  0
# 4    0  1
# ..  .. ..
# 886  1  0
# 887  0  0
# 888  0  1
# 889  0  0
# 890  0  1
#
# [891 rows x 2 columns]

# %%
embarked = pd.get_dummies(data['Embarked'],drop_first=True)
embarked
# Out:
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 2 columns]

# %%
gender = pd.get_dummies(data['Sex'],drop_first=True)
gender
# Out:
#       male
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# ..     ...
# 886   True
# 887  False
# 888  False
# 889   True
# 890   True
#
# [891 rows x 1 columns]

# %%
final_data = pd.concat([data,pclass,gender,embarked],axis=1)
final_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# 886                              Montvila, Rev. Juozas    male  27.000000
# 887                       Graham, Miss. Margaret Edith  female  19.000000
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  29.699118
# 889                              Behr, Mr. Karl Howell    male  26.000000
# 890                                Dooley, Mr. Patrick    male  32.000000
#
#      SibSp  Parch            Ticket     Fare Cabin Embarked  2  3   male  \
# 0        1      0         A/5 21171   7.2500   NaN        S  0  1   True
# 1        1      0          PC 17599  71.2833   C85        C  0  0  False
# 2        0      0  STON/O2. 3101282   7.9250   NaN        S  0  1  False
# 3        1      0            113803  53.1000  C123        S  0  0  False
# 4        0      0            373450   8.0500   NaN        S  0  1   True
# ..     ...    ...               ...      ...   ...      ... .. ..    ...
# 886      0      0            211536  13.0000   NaN        S  1  0   True
# 887      0      0            112053  30.0000   B42        S  0  0  False
# 888      1      2        W./C. 6607  23.4500   NaN        S  0  1  False
# 889      0      0            111369  30.0000  C148        C  0  0   True
# 890      0      0            370376   7.7500   NaN        Q  0  1   True
#
#          Q      S
# 0    False   True
# 1    False  False
# 2    False   True
# 3    False   True
# 4    False   True
# ..     ...    ...
# 886  False   True
# 887  False   True
# 888  False   True
# 889  False  False
# 890   True  False
#
# [891 rows x 17 columns]

# %%
final_data.drop(columns=['PassengerId','Name','Pclass','Sex','Ticket','Embarked'],inplace=True)
final_data.head()
# Out:
#    Survived   Age  SibSp  Parch     Fare Cabin  2  3   male      Q      S
# 0         0  22.0      1      0   7.2500   NaN  0  1   True  False   True
# 1         1  38.0      1      0  71.2833   C85  0  0  False  False  False
# 2         1  26.0      0      0   7.9250   NaN  0  1  False  False   True
# 3         1  35.0      1      0  53.1000  C123  0  0  False  False   True
# 4         0  35.0      0      0   8.0500   NaN  0  1   True  False   True
